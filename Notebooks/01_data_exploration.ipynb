# %%
import pandas as pd

# Define file path
file_path = "../data/raw/cdi_household_clean_nopii.dta"  # Adjust path as needed

# Load the .dta file
df = pd.read_stata(file_path, convert_categoricals=False)

# Display basic info
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Columns: 9565 entries, duration to time_wives
# dtypes: datetime64[ns](45), float32(69), float64(8284), int16(1), int32(7), int8(344), object(815)
# memory usage: 105.9+ MB
#    duration  region  district   vill    village community_type  restore_check  \
# 0      7452       5        51  51024  Koitienko        RESTORE            1.0
# 1      5408       4        41  41011     KLODIO     COMPARISON            NaN
# 2      6208       5        51  51028   Ananguié        RESTORE            0.0
# 3      3228       7        74  74003    BOHOUIN     COMPARISON            NaN
# 4      8314       4        41  41011     KLODIO     COMPARISON            NaN
#
#    hhid_restore village_restore gender_restore  ... cocoa_sell_kg  \
# 0           0.0                                 ...        1105.0
# 1           NaN                                 ...           NaN
# 2           NaN                                 ...         212.5
# 3           NaN                                 ...           NaN
# 4           NaN                                 ...           NaN
#
#    cocoa_price_kg farm_a_1_acres farm_a_2_acres  farm_a_3_acres  \
# 0       11.764706       4.942100      12.355250             NaN
# 1             NaN       1.235525      12.355250         2.47105
# 2     1000.000000       4.942100            NaN             NaN
# 3             NaN       2.471050            NaN             NaN
# 4             NaN      42.007851      51.892052             NaN
#
#    farm_a_4_acres  farm_a_5_acres  total_landcleared_acres     time_hh  \
# 0             NaN             NaN                      NaN  127.699997
# 1             NaN             NaN                      NaN   88.000000
# 2             NaN             NaN                      NaN  102.650002
# 3             NaN             NaN                      NaN   57.183334
# 4             NaN             NaN                      NaN  143.449997
#
#   time_wives
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4  58.316666
#
# [5 rows x 9565 columns]

# %%
# Count missing values per column
df.isnull().sum().sort_values(ascending=False)
# Out:
# shade_alivenow_1_16     1504
# shadetree_index_1_17    1504
# shadetree_calc_1_17     1504
# shade_tree_tot_1_17     1504
# shade_natural_1_17      1504
#                         ...
# lead_vill_11               0
# lead_vill_12               0
# lead_vill_13               0
# lead_vill_97               0
# consent_record             0
# Length: 9565, dtype: int64

# %%
df.describe()
# Out:
#            duration       region     district          vill  restore_check  \
# count   1505.000000  1505.000000  1505.000000   1505.000000     738.000000
# mean    6957.524252     5.161462    53.061130  52846.528239       0.555556
# min     1631.000000     4.000000    41.000000  41001.000000       0.000000
# 25%     5208.000000     4.000000    41.000000  41028.000000       0.000000
# 50%     6497.000000     5.000000    51.000000  51023.000000       1.000000
# 75%     8233.000000     6.000000    62.000000  54002.000000       1.000000
# max    28332.000000     7.000000    76.000000  75001.000000       1.000000
# std     2653.697025     1.102995    11.557741  11324.051792       0.497241
#
#        hhid_restore  confirm_restore  any_questions  consent  consent_record  \
# count    410.000000            410.0    1505.000000   1505.0     1505.000000
# mean   50830.239024              1.0       0.360133      1.0        0.985382
# min        0.000000              1.0       0.000000      1.0        0.000000
# 25%    50454.250000              1.0       0.000000      1.0        1.000000
# 50%    50964.000000              1.0       0.000000      1.0        1.000000
# 75%    51403.750000              1.0       1.000000      1.0        1.000000
# max    51847.000000              1.0       1.000000      1.0        1.000000
# std     2571.958581              0.0       0.480198      0.0        0.120058
#
#        ...  cocoa_sell_kg  cocoa_price_kg  farm_a_1_acres  farm_a_2_acres  \
# count  ...   8.230000e+02      823.000000     1505.000000      975.000000
# mean   ...   2.395653e+03      814.879883       11.295180       12.340106
# min    ...   0.000000e+00        0.042857        0.617763        0.617763
# 25%    ...   2.800000e+02      850.000000        4.942100        2.471050
# 50%    ...   5.400000e+02     1000.000000        7.413150        4.942100
# 75%    ...   1.040000e+03     1000.000000       12.355250        8.648675
# max    ...   1.200000e+06    12000.000000      190.270844     4947.041992
# std    ...   4.183907e+04      551.531799       12.099500      158.433426
#
#        farm_a_3_acres  farm_a_4_acres  farm_a_5_acres  \
# count      443.000000      174.000000       79.000000
# mean        17.208073        6.365794        5.378443
# min          0.000000        0.000000        0.617763
# 25%          2.471050        2.471050        1.235525
# 50%          4.942100        4.942100        2.471050
# 75%          7.413150        7.413150        7.413150
# max       4996.462891       65.482826       24.710501
# std        237.193359        8.251189        5.829566
#
#        total_landcleared_acres      time_hh   time_wives
# count               204.000000  1503.000000   502.000000
# mean                  1.944362   143.681305    71.983437
# min                   0.000000     0.683333     4.566667
# 25%                   1.235525    85.750000    43.833332
# 50%                   1.235525   109.183334    57.166668
# 75%                   2.471050   141.975006    77.195831
# max                  14.826300  9561.250000  1506.116699
# std                   1.598416   294.980865    96.617920
#
# [8 rows x 8750 columns]
